# %%
import pandas as pd

# %%
dataset=pd.read_csv('Maternal.csv')
dataset
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0      25         130           80  15.0      98.0         86  high risk
# 1      35         140           90  13.0      98.0         70  high risk
# 2      29          90           70   8.0     100.0         80  high risk
# 3      30         140           85   7.0      98.0         70  high risk
# 4      35         120           60   6.1      98.0         76   low risk
# ...   ...         ...          ...   ...       ...        ...        ...
# 1009   22         120           60  15.0      98.0         80  high risk
# 1010   55         120           90  18.0      98.0         60  high risk
# 1011   35          85           60  19.0      98.0         86  high risk
# 1012   43         120           90  18.0      98.0         70  high risk
# 1013   32         120           65   6.0     101.0         76   mid risk
#
# [1014 rows x 7 columns]

# %%
x=dataset.iloc[:,[0,1,2,3,4,5]].values

# %%
x[0]
# Out:
# array([ 25., 130.,  80.,  15.,  98.,  86.])

# %%
y=dataset.iloc[:,[6]].values

# %%
y[0]
# Out:
# array(['high risk'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
# Out:
# c:\Users\user\anaconda3\lib\site-packages\scipy\__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
model=KNeighborsClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-b633af2c521b> in <module>
# ----> 1 model=KNeighborsClassifier()
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
model=KNeighborsClassifier()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-b633af2c521b> in <module>
# ----> 1 model=KNeighborsClassifier()
#
# NameError: name 'KNeighborsClassifier' is not defined

# %%
import numpy as np
ytrain=np.ravel(ytrain)
model.fit(xtrain,ytrain)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-e36032e1bdcf> in <module>
#       1 import numpy as np
# ----> 2 ytrain=np.ravel(ytrain)
#       3 model.fit(xtrain,ytrain)
#
# NameError: name 'ytrain' is not defined

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=100)

# %%
print(xtrain[0],len(xtrain))
# Out:
# [ 32.  140.  100.    6.9  98.   78. ] 811

# %%
print(xtest[0],len(xtest))
# Out:
# [ 10. 100.  50.   6.  99.  70.] 203

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()

# %%
import numpy as np
ytrain=np.ravel(ytrain)
model.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier()

# %%
testdata=np.array([[25,130,80,15,98,86]])

# %%
result=model.predict(testdata)
result
# Out:
# array(['low risk'], dtype=object)

# %%
ypred=model.predict(xtest)

# %%
print(ypred)
# Out:
# ['mid risk' 'low risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'high risk' 'low risk' 'low risk' 'mid risk' 'low risk' 'high risk'
#  'mid risk' 'low risk' 'mid risk' 'mid risk' 'high risk' 'high risk'
#  'low risk' 'mid risk' 'high risk' 'low risk' 'low risk' 'high risk'
#  'mid risk' 'low risk' 'low risk' 'low risk' 'mid risk' 'low risk'
#  'low risk' 'low risk' 'high risk' 'low risk' 'low risk' 'mid risk'
#  'high risk' 'low risk' 'low risk' 'mid risk' 'low risk' 'high risk'
#  'high risk' 'mid risk' 'high risk' 'high risk' 'mid risk' 'low risk'
#  'low risk' 'mid risk' 'low risk' 'low risk' 'high risk' 'high risk'
#  'mid risk' 'mid risk' 'mid risk' 'low risk' 'mid risk' 'high risk'
#  'low risk' 'low risk' 'mid risk' 'high risk' 'mid risk' 'mid risk'
#  'low risk' 'mid risk' 'low risk' 'mid risk' 'high risk' 'low risk'
#  'high risk' 'low risk' 'mid risk' 'mid risk' 'mid risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'mid risk' 'mid risk' 'low risk'
#  'low risk' 'mid risk' 'low risk' 'low risk' 'high risk' 'low risk'
#  'high risk' 'low risk' 'high risk' 'high risk' 'high risk' 'high risk'
#  'low risk' 'low risk' 'low risk' 'mid risk' 'low risk' 'high risk'
#  'low risk' 'low risk' 'mid risk' 'mid risk' 'low risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'low risk' 'low risk' 'low risk' 'low risk' 'mid risk' 'low risk'
#  'high risk' 'low risk' 'high risk' 'low risk' 'high risk' 'mid risk'
#  'mid risk' 'low risk' 'mid risk' 'high risk' 'low risk' 'mid risk'
#  'high risk' 'mid risk' 'low risk' 'high risk' 'low risk' 'low risk'
#  'high risk' 'low risk' 'mid risk' 'mid risk' 'low risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'high risk' 'high risk' 'mid risk'
#  'mid risk' 'low risk' 'mid risk' 'mid risk' 'low risk' 'mid risk'
#  'low risk' 'low risk' 'low risk' 'high risk' 'high risk' 'low risk'
#  'high risk' 'mid risk' 'mid risk' 'high risk' 'low risk' 'high risk'
#  'high risk' 'mid risk' 'mid risk' 'high risk' 'low risk' 'high risk'
#  'low risk' 'high risk' 'mid risk' 'mid risk' 'mid risk' 'mid risk'
#  'low risk' 'mid risk' 'low risk' 'mid risk' 'mid risk' 'high risk'
#  'high risk' 'mid risk' 'low risk' 'low risk' 'mid risk' 'low risk'
#  'mid risk' 'low risk' 'low risk' 'low risk' 'high risk' 'high risk'
#  'low risk' 'mid risk' 'high risk' 'low risk' 'low risk']

# %%
from sklearn.metrics import accuracy_score

# %%
score=accuracy_score(ytest,ypred)
score*100
# Out:
# 68.4729064039409

# %%
import joblib
joblib.dump(model,"knncropmodel.pkl")
# Out:
# ['knncropmodel.pkl']
